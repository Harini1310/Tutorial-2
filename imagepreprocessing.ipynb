# %% [markdown]
# <a href="https://colab.research.google.com/github/Harini1310/Tutorial-2/blob/master/imagepreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt

#Import image
image = cv2.imread("or4.jpg")

#Show the image with matplotlib
plt.imshow(image)
plt.show()

# %%
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
from skimage import data
img = cv2.imread("or4.jpg")
img_gray = rgb2gray(img)

plt.imshow(img_gray)
plt.show()
