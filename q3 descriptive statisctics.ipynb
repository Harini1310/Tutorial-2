# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-5966cc0a-6785-4685-a6cb-f6a633f913ee" name="files[]" multiple disabled />
#      <output id="result-5966cc0a-6785-4685-a6cb-f6a633f913ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving athlete.csv to athlete.csv

# %%
from datascience import *
import numpy as np
import pandas as pd
from scipy import stats

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
data = pd.read_csv("athlete.csv", sep = ',')
data

# %%
data[['Age', 'Height', 'Weight', 'Year']].median()
# Out:
# Age         24.0
# Height     175.0
# Weight      70.0
# Year      1988.0
# dtype: float64

# %%
mean_data = ["Year"]
geometric_mean = stats.gmean(data.loc[:,mean_data])
geometric_mean
# Out:
# array([1978.15095596])

# %%
harmonic_mean = stats.hmean(data.loc[:,mean_data])
harmonic_mean
# Out:
# array([1977.92150549])

# %%
describe_athlete = data.describe()
describe_athlete
# Out:
#                   ID            Age  ...         Weight           Year
# count  271116.000000  261642.000000  ...  208241.000000  271116.000000
# mean    68248.954396      25.556898  ...      70.702393    1978.378480
# std     39022.286345       6.393561  ...      14.348020      29.877632
# min         1.000000      10.000000  ...      25.000000    1896.000000
# 25%     34643.000000      21.000000  ...      60.000000    1960.000000
# 50%     68205.000000      24.000000  ...      70.000000    1988.000000
# 75%    102097.250000      28.000000  ...      79.000000    2002.000000
# max    135571.000000      97.000000  ...     214.000000    2016.000000
#
# [8 rows x 5 columns]

# %%
first_quartile = describe_athlete.iloc[4]
third_quartile = describe_thlete.iloc[6]
inter_quartile = third_quartile - first_quartile
inter_quartile
# Out:
# ID        67454.25
# Age           7.00
# Height       15.00
# Weight       19.00
# Year         42.00
# dtype: float64

# %%
data.boxplot(column=["Age","Weight","Year"])

# %%
plots.scatter(data.Age,data.Year)

# %%
month_count = data.groupby("Weight").size()
month_count.plot.bar()

# %%
month_count.plot.pie()

# %%
data.hist(by='Year',column=["Height","Weight"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa389dd0710>,
# ...
#       dtype=object)
